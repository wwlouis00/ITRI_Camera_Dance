# %%
# !nvidia-smi
# Out:
# Thu Mar 21 16:21:56 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.14              Driver Version: 550.54.14      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3090        Off |   00000000:1E:00.0 Off |                  N/A |
# | 30%   34C    P8             26W /  350W |      10MiB /  24576MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()

# %% [markdown]
# # 坐姿姿體

# %% [markdown]
# # 站姿姿體

# %%
# from roboflow import Roboflow
# rf = Roboflow(api_key="Ss1j0YPJJbz42COV93mO")
# project = rf.workspace("dance-ybkzm").project("itri_dance_first")
# version = project.version(6)
# dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.1.23, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to ITRI_dance_first-6 in yolov8:: 100%|██████████| 11782/11782 [00:13<00:00, 899.91it/s]

# %%
# !yolo task=detect mode=train model=yolov8n-pose.pt data={dataset.location}/data.yaml epochs=50 imgsz=640
# !yolo task=detect mode=train model=yolov8x.pt data=/root/Work/itri_dance/first_pose/data.yaml epochs=100 imgsz=640
# Out:
# New https://pypi.org/project/ultralytics/8.1.30 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.226 🚀 Python-3.11.5 torch-2.1.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3090, 24253MiB)
# ...

# %%
Image(filename=f'/root/.pyenv/runs/detect/train7/confusion_matrix.png', width=800)

# %%
Image(filename=f'/root/.pyenv/runs/detect/train7/results.png', width=900)

# %%
# !yolo task=detect mode=val model=/root/.pyenv/runs/detect/train6/weights/best.pt data=/root/Work/itri_dance/ITRI_dance_8pose-3/data.yaml
# !yolo task=detect mode=val model=/root/.pyenv/runs/detect/train4/weights/best.pt data={dataset.location}/data.yaml
# Out:
# ^C
# Traceback (most recent call last):
#   File "/root/.pyenv/versions/3.11.6/bin/yolo", line 5, in <module>
#     from ultralytics.cfg import entrypoint
#   File "/root/.pyenv/versions/3.11.6/lib/python3.11/site-packages/ultralytics/__init__.py", line 5, in <module>
#     from ultralytics.data.explorer.explorer import Explorer
#   File "/root/.pyenv/versions/3.11.6/lib/python3.11/site-packages/ultralytics/data/explorer/__init__.py", line 3, in <module>
#     from .utils import plot_query_result
#   File "/root/.pyenv/versions/3.11.6/lib/python3.11/site-packages/ultralytics/data/explorer/utils.py", line 8, in <module>
#     import pandas as pd
#   File "/root/.pyenv/versions/3.11.6/lib/python3.11/site-packages/pandas/__init__.py", line 46, in <module>
#     from pandas.core.api import (
#   File "/root/.pyenv/versions/3.11.6/lib/python3.11/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
# ...

# %%
# !yolo task=detect mode=predict model=/root/.pyenv/runs/detect/train13/weights/best.pt conf=0.5 source=/root/Work/itri_dance/ITRI_dance_8pose-3/test/images save_txt=true save_conf=true
# !yolo task=detect mode=predict model=/home/wwlouis/.pyenv/runs/detect/train5/weights/best.pt conf=0.5 source={dataset.location}/test/images save_txt=true save_conf=true
# Out:
# Ultralytics YOLOv8.1.23 🚀 Python-3.11.6 torch-2.1.2+cu121 CUDA:0 (Quadro RTX 8000, 48586MiB)
# Model summary (fused): 268 layers, 68126457 parameters, 0 gradients, 257.4 GFLOPs
#
# image 1/91 /root/Work/itri_dance/ITRI_dance_8pose-3/test/images/130_mp4-0042_jpg.rf.090b718c999db2a365a546cb4cd7f7cd.jpg: 640x640 1 LR_1, 27.9ms
# image 2/91 /root/Work/itri_dance/ITRI_dance_8pose-3/test/images/131_mp4-0074_jpg.rf.12c1b24bbeafab4540b91df9e3a880a6.jpg: 640x640 1 LR_1, 27.7ms
# image 3/91 /root/Work/itri_dance/ITRI_dance_8pose-3/test/images/132_mp4-0037_jpg.rf.bfd3530dfff501237f765eeed8bbc7c3.jpg: 640x640 1 LR_1, 27.6ms
# image 4/91 /root/Work/itri_dance/ITRI_dance_8pose-3/test/images/132_mp4-0048_jpg.rf.40e64ecd71b76e569cee294a846efb04.jpg: 640x640 1 LR_1, 27.6ms
# image 5/91 /root/Work/itri_dance/ITRI_dance_8pose-3/test/images/133_mp4-0074_jpg.rf.7085df94e44fc733802c6bc7a36259e6.jpg: 640x640 1 LR_1, 27.6ms
# ...

# %%
Image(filename=f'/root/.pyenv/runs/detect/train7/val_batch0_pred.jpg', width=900)

# %%
Image(filename=f'/root/.pyenv/runs/detect/train7/val_batch1_pred.jpg', width=900)
